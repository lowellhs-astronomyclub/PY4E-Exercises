# %% [markdown]
# Exercise 6
#
# Rewrite your pay computation with time-and-a-half for overtime (for the purposes of this exercise, let's say that a normal working week is 40 hours) and create a function called `computepay` which takes two parameters (hours and rate).
#
# Example Output:
#
# `Enter Hours: 45`
#
# `Enter Rate: 10`
#
# `Pay: 475.0`

# %%
# define your function here
def computepay(hours, rate):
    overtimeHrs = hours-40
    if hours > 40:
        return 40*rate+overtimeHrs*1.5*rate
    else:
        return hours*rate

# then call your function with a parameter of your choice and print the result
# test it out with different parameter values!
hours = int(input('Enter hours: '))
rate = int(input('Enter rate per hour: '))

print("Pay:", computepay(hours, rate))
# Out:
# Enter hours: 48
# Enter rate per hour: 2
# Pay: 104.0

# %% [markdown]
# Exercise 7
#
# Define a function called `computegrade` that takes a percentage as its parameter and returns the appropriate grade as a string.
#
# | Percentage | Grade |
# |------------|-------|
# | >= 0.9     | A     |
# | >= 0.8     | B     |
# | >= 0.7     | C     |
# | >= 0.6     | D     |
# | < 0.6      | F     |
#
# Example Output:
#
# `Enter score: 0.95`
#
# `A`

# %%
# define your function here
def computegrade(percentage):
    if percentage >= 0.9:
        return 'A'
    elif percentage >= 0.8:
        return 'B'
    elif percentage >= 0.7:
        return 'C'
    elif percentage >= 0.6:
        return 'D'
    else:
        return 'F'
    
# then call your function with a parameter of your choice and print the result
# test it out with different parameter values!
percentage = float(input('Enter percentage: '))
print('Grade:', computegrade(percentage))
# Out:
# Enter percentage: 0.68
# Grade: D
